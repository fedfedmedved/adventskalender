# %%
import re

# %% [markdown]
# import numpy as np

# %%
data = open('data.txt').read().splitlines()

# %%
type(data)
# Out:
# list

# %%
data[0]
# Out:
# 'dqfournine5four2jmlqcgv'

# %%
a = lambda i: re.findall('\d', data[i]) #makes a list of all digits in a string

# %%
b = lambda i: a(i)[0] + a(i)[-1] #concatenates the first and last digit into a single string

# %%
int(b(0))
# Out:
# 52

# %%
len(data)
# Out:
# 1001

# %%
processed_data = [a(i) for i in data]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 processed_data = [a(i) for i in data]
#
# Cell In[130], line 1, in <listcomp>(.0)
# ----> 1 processed_data = [a(i) for i in data]
#
# Cell In[115], line 1, in <lambda>(i)
# ----> 1 a = lambda i: re.findall('\d', data[i])
#
# TypeError: list indices must be integers or slices, not str

# %%
processed_data
# Out:
# [52,
#  77,
#  44,
#  55,
#  55,
#  95,
#  44,
#  35,
#  41,
#  48,
#  67,
#  17,
#  15,
#  83,
#  44,
#  66,
#  59,
#  64,
#  29,
#  26,
#  11,
#  23,
#  96,
#  99,
#  14,
#  68,
#  88,
#  87,
#  77,
#  66,
#  55,
#  33,
#  18,
#  11,
#  33,
#  62,
#  88,
#  88,
#  91,
#  77,
#  13,
#  13,
#  44,
#  21,
#  33,
#  53,
#  99,
#  71,
#  56,
#  88,
#  91,
#  54,
#  33,
#  44,
#  21,
#  76,
#  26,
#  58,
#  11,
#  44,
#  55,
#  92,
#  58,
#  55,
#  34,
#  55,
#  99,
#  88,
#  16,
#  51,
#  29,
#  38,
#  33,
#  16,
#  19,
#  33,
#  94,
#  17,
#  17,
#  83,
#  44,
#  55,
#  88,
#  44,
#  69,
#  63,
#  44,
#  83,
#  44,
#  99,
#  44,
#  33,
#  99,
#  62,
#  79,
#  55,
#  33,
#  82,
#  97,
#  23,
#  88,
#  37,
#  88,
#  66,
#  93,
#  33,
#  17,
#  84,
#  86,
#  33,
#  65,
#  19,
#  82,
#  33,
#  22,
#  31,
#  44,
#  69,
#  22,
#  99,
#  66,
#  35,
#  22,
#  23,
#  58,
#  31,
#  77,
#  28,
#  33,
#  19,
#  34,
#  98,
#  66,
#  73,
#  56,
#  34,
#  55,
#  79,
#  96,
#  25,
#  27,
#  77,
# ...

# %%
sum = 0
for i in processed_data:
    sum = i + sum

# %%
processed_data = [x in processed_data]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 processed_data = [x[0] for x in processed_data]
#
# Cell In[106], line 1, in <listcomp>(.0)
# ----> 1 processed_data = [x[0] for x in processed_data]
#
# IndexError: list index out of range

# %%
processed_data
# Out:
# [list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
#  list[0],
# ...

# %%
re.finall('\d')

# %%
a = np.random.rand(20,20)
a = a*100
a = a.astype(int)

# %%
a[0:2,0:2]
# Out:
# array([[ 5, 53],
#        [ 9, 12]])

# %%
a
# Out:
# array([[ 5, 53, 92,  7, 97, 28, 14, 61, 51, 37, 47, 96, 80, 93, 12, 59,
#         97, 66, 31, 90],
#        [ 9, 12, 65, 32, 89, 97, 60, 77, 54, 63, 57, 82, 36, 89, 55, 95,
#         72, 55, 46, 79],
#        [37, 48, 31, 15, 85, 90, 63, 25, 33, 73, 20, 53, 36, 58, 22, 94,
#         29, 22, 94, 46],
#        [25, 42, 62, 98, 38, 93, 22, 42, 46, 80, 15, 10, 92, 53, 58, 68,
#         90, 91, 21,  9],
#        [21, 19, 17,  7, 79, 35,  5, 69, 99, 34, 23, 50, 35, 93,  5, 46,
#         51, 37, 88, 16],
#        [97, 92,  2, 18, 95, 16, 72, 58, 94, 93, 75, 21,  7, 72, 61, 46,
#         41, 44, 16, 21],
#        [92, 29, 39, 86, 87, 61, 31, 78, 43, 70, 33, 56, 87,  6,  0, 42,
#         38, 78, 70,  7],
#        [16, 73, 85, 23, 97, 72, 64, 74, 13, 35, 17, 46, 29, 62, 99, 68,
#         27, 79, 23, 34],
#        [47, 69, 37, 36, 51, 78, 35, 67, 37, 41, 30, 53, 78, 14, 95, 65,
#          8, 55, 15, 90],
#        [26, 67, 48, 75, 74,  8, 35, 28, 32, 86, 39,  2, 82, 26, 60, 45,
# ...

# %%
s = 'ACA3ABAACAAAB'

# %%
m = 'I refer to https://google.com and I never refer http://www.baidu.com (a) and (b)'

# %%
re.findall('\(.\)', m)
# Out:
# ['(a)', '(b)']

# %%
np.linspace(1 ,4, 4).ndim()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 np.linspace(1 ,4, 4).ndim() ==1
#
# TypeError: 'int' object is not callable

# %%
a1 = np.random.rand(4)

# %%
a1.ndim
# Out:
# 1

# %%
import re
string = 'bat, lat, mat, bet, let, met, bit, lit, mit, bot, lot, mot'
result = re.findall('b[ao]t', string)
print(result)
